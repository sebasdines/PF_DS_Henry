# %% [markdown]
# # YELP

# %%
#Importamos las librerías necesarias
import pandas as pd
import json
import re
import folium
from folium.plugins import HeatMap

# %% [markdown]
# ## Businesses

# %%
#Leemos el archivo .pkl 
df_business=pd.read_pickle('Data/Yelp/business.pkl')

# %%
#Observamos el contenido del dataframe
df_business.head()
# Out:
#               business_id                      name  \
# 0  Pns2l4eNsfO8kk83dixA6A  Abby Rappoport, LAC, CMQ
# 1  mpf3x-BjTdTEA3yCZrAYPw             The UPS Store
# 2  tUFrWirKiKi_TAnsVWINQQ                    Target
# 3  MTSW4McQd7CbVtyjqoe9mw        St Honore Pastries
# 4  mWMc6_wTdE0EUBKIGXDVfA  Perkiomen Valley Brewery
#
#                            address           city state postal_code  \
# 0           1616 Chapala St, Ste 2  Santa Barbara   NaN       93101
# 1  87 Grasso Plaza Shopping Center         Affton   NaN       63123
# 2             5255 E Broadway Blvd         Tucson   NaN       85711
# 3                      935 Race St   Philadelphia    CA       19107
# 4                    101 Walnut St     Green Lane    MO       18054
#
#     latitude   longitude stars review_count  ... state postal_code latitude  \
# 0  34.426679 -119.711197   5.0            7  ...   NaN         NaN      NaN
# 1  38.551126  -90.335695   3.0           15  ...   NaN         NaN      NaN
# 2  32.223236 -110.880452   3.5           22  ...   NaN         NaN      NaN
# 3  39.955505  -75.155564   4.0           80  ...   NaN         NaN      NaN
# 4  40.338183  -75.471659   4.5           13  ...   NaN         NaN      NaN
#
#   longitude stars review_count is_open attributes categories hours
# 0       NaN   NaN          NaN     NaN        NaN        NaN   NaN
# 1       NaN   NaN          NaN     NaN        NaN        NaN   NaN
# 2       NaN   NaN          NaN     NaN        NaN        NaN   NaN
# 3       NaN   NaN          NaN     NaN        NaN        NaN   NaN
# 4       NaN   NaN          NaN     NaN        NaN        NaN   NaN
#
# [5 rows x 28 columns]

# %%
#Observamos la información del dataframe
df_business.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 150346 entries, 0 to 150345
# Data columns (total 28 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   business_id   150346 non-null  object
#  1   name          150346 non-null  object
#  2   address       150346 non-null  object
#  3   city          150346 non-null  object
#  4   state         150343 non-null  object
#  5   postal_code   150346 non-null  object
#  6   latitude      150346 non-null  object
#  7   longitude     150346 non-null  object
#  8   stars         150346 non-null  object
#  9   review_count  150346 non-null  object
#  10  is_open       150346 non-null  object
#  11  attributes    136602 non-null  object
#  12  categories    150243 non-null  object
#  13  hours         127123 non-null  object
#  14  business_id   5 non-null       object
#  15  name          5 non-null       object
#  16  address       5 non-null       object
#  17  city          5 non-null       object
#  18  state         5 non-null       object
#  19  postal_code   5 non-null       object
#  20  latitude      5 non-null       object
#  21  longitude     5 non-null       object
#  22  stars         5 non-null       object
#  23  review_count  5 non-null       object
#  24  is_open       5 non-null       object
#  25  attributes    5 non-null       object
#  26  categories    5 non-null       object
#  27  hours         5 non-null       object
# dtypes: object(28)
# memory usage: 33.3+ MB

# %%
#Revisaremos los nulos
df_business.isnull().sum()
# Out:
# business_id          0
# name                 0
# address              0
# city                 0
# state                3
# postal_code          0
# latitude             0
# longitude            0
# stars                0
# review_count         0
# is_open              0
# attributes       13744
# categories         103
# hours            23223
# business_id     150341
# name            150341
# address         150341
# city            150341
# state           150341
# postal_code     150341
# latitude        150341
# longitude       150341
# stars           150341
# review_count    150341
# is_open         150341
# attributes      150341
# categories      150341
# hours           150341
# dtype: int64

# %%
#Eliminamos las columnas que se encuentran vacías y duplicadas, quedandome con la primera (que es la que tiene más datos)
df_business = df_business.loc[:, ~df_business.columns.duplicated(keep='first')]

# %%
#Verificamos que se hallan eliminado correctamente
df_business.isnull().sum()
# Out:
# business_id         0
# name                0
# address             0
# city                0
# state               3
# postal_code         0
# latitude            0
# longitude           0
# stars               0
# review_count        0
# is_open             0
# attributes      13744
# categories        103
# hours           23223
# dtype: int64

# %%
#Identificamos los estados de la columna state
df_business['state'].unique()
# Out:
# array([nan, 'CA', 'MO', 'AZ', 'PA', 'TN', 'FL', 'IN', 'LA', 'AB', 'NV',
#        'ID', 'DE', 'IL', 'NJ', 'NC', 'CO', 'WA', 'HI', 'UT', 'TX', 'MT',
#        'MI', 'SD', 'XMS', 'MA', 'VI', 'VT'], dtype=object)

# %%
#Identificamos los estados faltantes a través de las ciudades, verificamos si pertenecen al estado de Florida
df_business[df_business['state'].isnull()]
# Out:
#               business_id                      name  \
# 0  Pns2l4eNsfO8kk83dixA6A  Abby Rappoport, LAC, CMQ
# 1  mpf3x-BjTdTEA3yCZrAYPw             The UPS Store
# 2  tUFrWirKiKi_TAnsVWINQQ                    Target
#
#                            address           city state postal_code  \
# 0           1616 Chapala St, Ste 2  Santa Barbara   NaN       93101
# 1  87 Grasso Plaza Shopping Center         Affton   NaN       63123
# 2             5255 E Broadway Blvd         Tucson   NaN       85711
#
#     latitude   longitude stars review_count is_open  \
# 0  34.426679 -119.711197   5.0            7       0
# 1  38.551126  -90.335695   3.0           15       1
# 2  32.223236 -110.880452   3.5           22       0
#
#                                           attributes  \
# 0                      {'ByAppointmentOnly': 'True'}
# 1             {'BusinessAcceptsCreditCards': 'True'}
# 2  {'BikeParking': 'True', 'BusinessAcceptsCredit...
#
#                                           categories  \
# 0  Doctors, Traditional Chinese Medicine, Naturop...
# 1  Shipping Centers, Local Services, Notaries, Ma...
# 2  Department Stores, Shopping, Fashion, Home & G...
#
#                                                hours
# 0                                               None
# 1  {'Monday': '0:0-0:0', 'Tuesday': '8:0-18:30', ...
# 2  {'Monday': '8:0-22:0', 'Tuesday': '8:0-22:0', ...

# %% [markdown]
# Ahora seleccionamos la información del estado de Florida. <br>
#
# En una primera instancia se decide filtrar por state=FL, pero se verifica que hay ciudades que no pertenecen al estado de Florida (por error en la columna estado). Por lo tanto, se decide buscar los códigos postales del Estado de Florida, a partir de esta fuente: https://xn--cdigos-postales-vrb.cybo.com/estados-unidos/florida/?p=3 y observamos que los valores van entre 32822 y 34997. Procedemos a filtrar el código postal.

# %%
#Primero, verificamos el tipo de dato de la columna postal_code
df_business['postal_code'].info()
# Out:
# <class 'pandas.core.series.Series'>
# Index: 150346 entries, 0 to 150345
# Series name: postal_code
# Non-Null Count   Dtype
# --------------   -----
# 150346 non-null  object
# dtypes: object(1)
# memory usage: 2.3+ MB

# %%
#Cambiamos el tipo de dato de la columna postal_code a string (se prueba pasar a entero pero hay str en la columna para otros estados)
df_business = df_business.copy()
df_business['postal_code']=df_business['postal_code'].astype(str)

# %%
#Filtramos el dataframe con el rango de códigos postales para quedarme con los del Estado de Florida.
df_business_florida = df_business[(df_business['postal_code'] >= '32822') & (df_business['postal_code'] <= '34997')]
df_business_florida
# Out:
#                    business_id                           name  \
# 7       qkRM_2X51Yqxk3btlwAQIg                 Temple Beth-El
# 10      UJsufbvfyfONHeWdvAHKjA                      Marshalls
# 11      eEOYSgkmpB90uNA7lDOMRA          Vietnamese Food Truck
# 13      jaxMSoInw8Poo3XeMJt8lQ                   Adams Dental
# 14      0bPLkL0QhhPO5kt1_EXmNQ           Zio's Italian Market
# ...                        ...                            ...
# 150280  37G3SzO7RS1qSthACCG5SQ           Tampa Bay Club Sport
# 150289  Fck8i0fNQCa22ERz5Fa21w              Thoughtful Moving
# 150292  esBGrrmuZzSiECyRBoKvvA  Colony Grill - St. Petersburg
# 150317  Q7JYAMNzI1IpUd2edflmTA                      21 Barber
# 150345  jV_XOycEzSlTx-65W906pg                        Sic Ink
#
#                           address              city state postal_code  \
# 7              400 Pasadena Ave S    St. Petersburg    PA       33707
# 10      21705 Village Lakes Sc Dr     Land O' Lakes    FL       34639
# 11                                        Tampa Bay    MO       33602
# 13              15 N Missouri Ave        Clearwater    FL       33755
# 14                  2575 E Bay Dr             Largo    FL       33771
# ...                           ...               ...   ...         ...
# 150280       380 105th Terrace Ne  Saint Petersburg    TN       33716
# 150289          5004 E Fowler Ave             Tampa    PA       33617
# 150292            670 Central Ave    St. Petersburg    FL       33701
# 150317            10937 56th St N    Temple Terrace    NJ       33617
# 150345      238 Apollo Beach Blvd      Apollo beach    TN       33572
#
#          latitude  longitude stars review_count is_open  \
# 7        27.76659 -82.732983   3.5            5       1
# 10      28.190459  -82.45738   3.5            6       1
# 11      27.955269  -82.45632   4.0           10       1
# 13      27.966235 -82.787412   5.0           10       1
# 14      27.916116 -82.760461   4.5          100       0
# ...           ...        ...   ...          ...     ...
# 150280  27.867754 -82.632602   2.5            7       0
# 150289  28.054934 -82.400832   2.0           27       1
# 150292  27.770872 -82.643069   4.5           38       1
# 150317  28.047632 -82.393519   4.5           18       1
# 150345  27.771002  -82.39491   4.5            9       1
#
#                                                attributes  \
# 7                                                    None
# 10      {'RestaurantsPriceRange2': '2', 'BikeParking':...
# 11      {'Alcohol': ''none'', 'OutdoorSeating': 'None'...
# 13                          {'ByAppointmentOnly': 'True'}
# 14      {'OutdoorSeating': 'False', 'RestaurantsGoodFo...
# ...                                                   ...
# 150280                            {'GoodForKids': 'True'}
# 150289  {'BusinessAcceptsCreditCards': 'True', 'ByAppo...
# 150292  {'RestaurantsPriceRange2': '2', 'RestaurantsAt...
# 150317  {'BusinessAcceptsCreditCards': 'True', 'Restau...
# 150345  {'WheelchairAccessible': 'True', 'BusinessAcce...
#
#                                                categories  \
# 7                     Synagogues, Religious Organizations
# 10                   Department Stores, Shopping, Fashion
# 11             Vietnamese, Food, Restaurants, Food Trucks
# 13      General Dentistry, Dentists, Health & Medical,...
# 14            Food, Delis, Italian, Bakeries, Restaurants
# ...                                                   ...
# 150280                          Active Life, Sports Clubs
# 150289  Packing Services, Home Services, Movers, Local...
# 150292  Bars, Beer Bar, Nightlife, Wine Bars, Pizza, R...
# 150317  Men's Hair Salons, Hair Salons, Barbers, Beaut...
# 150345  Beauty & Spas, Permanent Makeup, Piercing, Tattoo
#
#                                                     hours
# 7       {'Monday': '9:0-17:0', 'Tuesday': '9:0-17:0', ...
# 10      {'Monday': '9:30-21:30', 'Tuesday': '9:30-21:3...
# 11      {'Monday': '11:0-14:0', 'Tuesday': '11:0-14:0'...
# 13      {'Monday': '7:30-15:30', 'Tuesday': '7:30-15:3...
# 14      {'Monday': '10:0-18:0', 'Tuesday': '10:0-20:0'...
# ...                                                   ...
# 150280                                               None
# 150289  {'Monday': '22:0-22:30', 'Tuesday': '8:0-19:0'...
# 150292  {'Monday': '11:30-23:0', 'Tuesday': '11:30-23:...
# 150317  {'Monday': '9:0-20:0', 'Tuesday': '9:0-20:0', ...
# 150345  {'Tuesday': '12:0-19:0', 'Wednesday': '12:0-19...
#
# [26322 rows x 14 columns]

# %%
#Revisamos las dimensiones del dataframe
df_business_florida.shape
# Out:
# (26322, 14)

# %% [markdown]
# Vamos a verificar a partir de los datos de longitud y latitud que todos los registros seleccionamos se encuentran en Florida.

# %%
# Creamos un mapa
m = folium.Map(location=[df_business_florida['latitude'].mean(), df_business_florida['longitude'].mean()], zoom_start=10)

# Creamos la lista de coordenadas
locations = list(zip(df_business_florida['latitude'], df_business_florida['longitude']))

# lo agregamos al mapa de calor
HeatMap(locations).add_to(m)

# Mostrar el mapa
m.save('heatmap_florida.html')  # Guardamos el mapa como archivo HTML
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c92a021a8680129ce6416cba60f93d55 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@main/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c92a021a8680129ce6416cba60f93d55&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c92a021a8680129ce6416cba60f93d55 = L.map(
#                 &quot;map_c92a021a8680129ce6416cba60f93d55&quot;,
#                 {
#                     center: [27.980486812094036, -82.56899216017689],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b5977dd6c70200e69bcb24108aca6ce9 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_c92a021a8680129ce6416cba60f93d55);
#
#
#             var heat_map_f8b656adaded0076e27e4cc79ba2fe9b = L.heatLayer(
#                 [[27.76659, -82.732983], [28.1904587953, -82.4573802199], [27.9552692, -82.4563199], [27.966235, -82.787412], [27.9161159, -82.7604608], [27.8083394, -82.6361678], [28.0103596, -82.4300416], [28.0462028173, -82.5050526736], [27.9605142, -82.506127], [27.9954501644, -82.5081187], [28.3326007, -82.6681066], [27.8553467494, -82.7363080904], [28.1962523878, -82.3806153496], [27.890814, -82.5023464], [27.7694046, -82.767317], [28.1477204, -82.7425681], [27.7747314, -82.6402836], [27.9586132, -82.5325949], [28.1961683557, -82.464425454], [27.935753, -82.4764699], [27.7713566, -82.6586115], [27.894167, -82.779866], [27.8931855254, -82.6876049487], [28.0458684582, -82.515059], [27.9251193, -82.7959877], [27.8652573, -82.3260903], [27.7972626, -82.7339127], [28.0548882706, -82.3995484], [27.798503, -82.7987502], [28.192191035, -82.396367], [27.9657471097, -82.7989008], [27.9987001903, -82.5822531301], [28.2502179787, -82.6824409515], [28.09236, -82.500588], [27.9232395, -82.402873], [28.0787347875, -82.5063104158], [28.0699667, -82.4187315], [27.9371659, -82.2699586], [27.9803985924, -82.5377866183], [27.9767745, -82.5374233], [28.0022293, -82.5943283], [27.5843003458, -82.6139500829], [28.055212, -82.399374], [28.0112177255, -82.6113298722], [28.0464757264, -82.3928064047], [27.9419745389, -82.5053069603], [27.9989575, -82.4514338], [27.806517, -82.749065], [27.8037453386, -82.8031028436], [27.8798076, -82.4936332], [27.9373704213, -82.3077001423], [27.82573, -82.694405], [27.8939198, -82.2943716], [28.0921362, -82.5785736], [27.7705318, -82.3703483], [27.9344684803, -82.2878021747], [28.237112, -82.6680235], [27.7305212, -82.7452183], [28.4939582, -82.6501344], [27.892834976, -82.7845353864], [27.8915738378, -82.2725105], [28.1782261, -82.7424346], [27.9402059, -82.4828837], [28.188219, -82.347274], [28.0420037, -82.6746125], [27.9464963776, -82.3555628732], [27.8623633, -82.4981215], [28.0535153, -82.4534422], [27.844945, -82.792501], [27.7379882, -82.7080321], [28.2375794, -82.3471278], [27.776811, -82.641157], [27.9404107, -82.3217459], [27.9646718, -82.5206425], [28.0536294, -82.4044188], [27.7823648981, -82.7816953479], [27.9444574, -82.4578244], [28.4934721999, -82.546930168], [28.0720088, -82.5109518], [28.1943032, -82.4986764], [27.9263727, -82.2859355], [28.0745649, -82.4599126], [28.07347, -82.459879], [27.865613, -82.7199909], [27.9788772, -82.8279609], [27.9210171, -82.3272616], [28.0662007, -82.6354932], [27.8928435529, -82.7453122398], [27.963, -82.777749], [27.7715736064, -82.6756190881], [27.9600238, -82.4444005], [28.0114997, -82.5828401], [27.8718285, -82.7502853], [27.7717231748, -82.6383055959], [27.964721464, -82.5198229405], [27.9279550671, -82.4784045787], [27.9963703, -82.580954], [28.2505165, -82.3737262], [28.497700000000002, -82.650015], [28.0686496, -82.5751466], [27.9588017985, -82.2789713027], [27.9345506, -82.2874462], [27.971329, -82.7078619], [27.944153, -82.46033], [28.185208, -82.406265], [28.1948998, -82.3542155], [28.0148425, -82.1231756], [27.8669377, -82.6450314], [28.4352625, -82.5669664], [28.4348331, -82.5427423], [28.056632, -82.4348671], [27.9451907, -82.7880287], [27.925332, -82.325395], [27.9916199, -82.7303756], [27.7969762597, -82.6381678127], [27.9684516983, -82.7621585038], [27.713401, -82.394372], [27.961201, -82.72336], [28.0424255, -82.5124529], [28.0451503082, -82.6812278379], [27.923037933, -82.4930161956], [27.9822896, -82.7057138], [28.4919153, -82.544815], [27.9910123, -82.1221107244], [27.7846206, -82.6383517], [28.2638132, -82.492625], [27.9082595, -82.2909146], [28.187946572, -82.3500558385], [27.8940624, -82.2719595], [28.0439, -82.6769], [27.894047, -82.2572688], [27.9112563, -82.315876], [27.8585758, -82.3397635], [27.7951457, -82.7299515], [27.870901, -82.7435853], [27.920067, -82.4989209], [28.290178,

# %% [markdown]
# Verificamos por el mapa que hay algunos datos que si bien el código postal pertenece a Florida, hay errores en los valores de longitud y latitude, por lo que se procede a eliminar esos 3 valores.
# Vemos que la longitud toma los valores: -86.651376442, -86.3266351 y -75.480487.
# Por lo tanto elijo quedarme con el rango de valores de Florida que es: -82.5939456 y -82.851044

# %%
df_business_florida = df_business_florida[df_business_florida['longitude'] !=-86.651376442]

# %%
df_business_florida = df_business_florida[df_business_florida['longitude'] !=-86.3266351]

# %%
df_business_florida = df_business_florida[df_business_florida['longitude'] !=-75.480487]

# %%
df_business_florida
# Out:
#                    business_id                           name  \
# 7       qkRM_2X51Yqxk3btlwAQIg                 Temple Beth-El
# 10      UJsufbvfyfONHeWdvAHKjA                      Marshalls
# 11      eEOYSgkmpB90uNA7lDOMRA          Vietnamese Food Truck
# 13      jaxMSoInw8Poo3XeMJt8lQ                   Adams Dental
# 14      0bPLkL0QhhPO5kt1_EXmNQ           Zio's Italian Market
# ...                        ...                            ...
# 150280  37G3SzO7RS1qSthACCG5SQ           Tampa Bay Club Sport
# 150289  Fck8i0fNQCa22ERz5Fa21w              Thoughtful Moving
# 150292  esBGrrmuZzSiECyRBoKvvA  Colony Grill - St. Petersburg
# 150317  Q7JYAMNzI1IpUd2edflmTA                      21 Barber
# 150345  jV_XOycEzSlTx-65W906pg                        Sic Ink
#
#                           address              city state postal_code  \
# 7              400 Pasadena Ave S    St. Petersburg    PA       33707
# 10      21705 Village Lakes Sc Dr     Land O' Lakes    FL       34639
# 11                                        Tampa Bay    MO       33602
# 13              15 N Missouri Ave        Clearwater    FL       33755
# 14                  2575 E Bay Dr             Largo    FL       33771
# ...                           ...               ...   ...         ...
# 150280       380 105th Terrace Ne  Saint Petersburg    TN       33716
# 150289          5004 E Fowler Ave             Tampa    PA       33617
# 150292            670 Central Ave    St. Petersburg    FL       33701
# 150317            10937 56th St N    Temple Terrace    NJ       33617
# 150345      238 Apollo Beach Blvd      Apollo beach    TN       33572
#
#          latitude  longitude stars review_count is_open  \
# 7        27.76659 -82.732983   3.5            5       1
# 10      28.190459  -82.45738   3.5            6       1
# 11      27.955269  -82.45632   4.0           10       1
# 13      27.966235 -82.787412   5.0           10       1
# 14      27.916116 -82.760461   4.5          100       0
# ...           ...        ...   ...          ...     ...
# 150280  27.867754 -82.632602   2.5            7       0
# 150289  28.054934 -82.400832   2.0           27       1
# 150292  27.770872 -82.643069   4.5           38       1
# 150317  28.047632 -82.393519   4.5           18       1
# 150345  27.771002  -82.39491   4.5            9       1
#
#                                                attributes  \
# 7                                                    None
# 10      {'RestaurantsPriceRange2': '2', 'BikeParking':...
# 11      {'Alcohol': ''none'', 'OutdoorSeating': 'None'...
# 13                          {'ByAppointmentOnly': 'True'}
# 14      {'OutdoorSeating': 'False', 'RestaurantsGoodFo...
# ...                                                   ...
# 150280                            {'GoodForKids': 'True'}
# 150289  {'BusinessAcceptsCreditCards': 'True', 'ByAppo...
# 150292  {'RestaurantsPriceRange2': '2', 'RestaurantsAt...
# 150317  {'BusinessAcceptsCreditCards': 'True', 'Restau...
# 150345  {'WheelchairAccessible': 'True', 'BusinessAcce...
#
#                                                categories  \
# 7                     Synagogues, Religious Organizations
# 10                   Department Stores, Shopping, Fashion
# 11             Vietnamese, Food, Restaurants, Food Trucks
# 13      General Dentistry, Dentists, Health & Medical,...
# 14            Food, Delis, Italian, Bakeries, Restaurants
# ...                                                   ...
# 150280                          Active Life, Sports Clubs
# 150289  Packing Services, Home Services, Movers, Local...
# 150292  Bars, Beer Bar, Nightlife, Wine Bars, Pizza, R...
# 150317  Men's Hair Salons, Hair Salons, Barbers, Beaut...
# 150345  Beauty & Spas, Permanent Makeup, Piercing, Tattoo
#
#                                                     hours
# 7       {'Monday': '9:0-17:0', 'Tuesday': '9:0-17:0', ...
# 10      {'Monday': '9:30-21:30', 'Tuesday': '9:30-21:3...
# 11      {'Monday': '11:0-14:0', 'Tuesday': '11:0-14:0'...
# 13      {'Monday': '7:30-15:30', 'Tuesday': '7:30-15:3...
# 14      {'Monday': '10:0-18:0', 'Tuesday': '10:0-20:0'...
# ...                                                   ...
# 150280                                               None
# 150289  {'Monday': '22:0-22:30', 'Tuesday': '8:0-19:0'...
# 150292  {'Monday': '11:30-23:0', 'Tuesday': '11:30-23:...
# 150317  {'Monday': '9:0-20:0', 'Tuesday': '9:0-20:0', ...
# 150345  {'Tuesday': '12:0-19:0', 'Wednesday': '12:0-19...
#
# [26319 rows x 14 columns]

# %% [markdown]
# Volvemos a graficar

# %%
# Creamos un mapa
m = folium.Map(location=[df_business_florida['latitude'].mean(), df_business_florida['longitude'].mean()], zoom_start=10)

# Creamos la lista de coordenadas
locations = list(zip(df_business_florida['latitude'], df_business_florida['longitude']))

# lo agregamos al mapa de calor
HeatMap(locations).add_to(m)

# Mostrar el mapa
m.save('heatmap_florida.html')  # Guardamos el mapa como archivo HTML
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e7bb3318da09ea665c204e6dea744c76 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@main/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e7bb3318da09ea665c204e6dea744c76&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e7bb3318da09ea665c204e6dea744c76 = L.map(
#                 &quot;map_e7bb3318da09ea665c204e6dea744c76&quot;,
#                 {
#                     center: [27.97927206307831, -82.5689636058222],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2c5c837a7dc3faac874bcd58a1322181 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_e7bb3318da09ea665c204e6dea744c76);
#
#
#             var heat_map_da0e4f2fb8a537528a0a362e729c4b36 = L.heatLayer(
#                 [[27.76659, -82.732983], [28.1904587953, -82.4573802199], [27.9552692, -82.4563199], [27.966235, -82.787412], [27.9161159, -82.7604608], [27.8083394, -82.6361678], [28.0103596, -82.4300416], [28.0462028173, -82.5050526736], [27.9605142, -82.506127], [27.9954501644, -82.5081187], [28.3326007, -82.6681066], [27.8553467494, -82.7363080904], [28.1962523878, -82.3806153496], [27.890814, -82.5023464], [27.7694046, -82.767317], [28.1477204, -82.7425681], [27.7747314, -82.6402836], [27.9586132, -82.5325949], [28.1961683557, -82.464425454], [27.935753, -82.4764699], [27.7713566, -82.6586115], [27.894167, -82.779866], [27.8931855254, -82.6876049487], [28.0458684582, -82.515059], [27.9251193, -82.7959877], [27.8652573, -82.3260903], [27.7972626, -82.7339127], [28.0548882706, -82.3995484], [27.798503, -82.7987502], [28.192191035, -82.396367], [27.9657471097, -82.7989008], [27.9987001903, -82.5822531301], [28.2502179787, -82.6824409515], [28.09236, -82.500588], [27.9232395, -82.402873], [28.0787347875, -82.5063104158], [28.0699667, -82.4187315], [27.9371659, -82.2699586], [27.9803985924, -82.5377866183], [27.9767745, -82.5374233], [28.0022293, -82.5943283], [27.5843003458, -82.6139500829], [28.055212, -82.399374], [28.0112177255, -82.6113298722], [28.0464757264, -82.3928064047], [27.9419745389, -82.5053069603], [27.9989575, -82.4514338], [27.806517, -82.749065], [27.8037453386, -82.8031028436], [27.8798076, -82.4936332], [27.9373704213, -82.3077001423], [27.82573, -82.694405], [27.8939198, -82.2943716], [28.0921362, -82.5785736], [27.7705318, -82.3703483], [27.9344684803, -82.2878021747], [28.237112, -82.6680235], [27.7305212, -82.7452183], [28.4939582, -82.6501344], [27.892834976, -82.7845353864], [27.8915738378, -82.2725105], [28.1782261, -82.7424346], [27.9402059, -82.4828837], [28.188219, -82.347274], [28.0420037, -82.6746125], [27.9464963776, -82.3555628732], [27.8623633, -82.4981215], [28.0535153, -82.4534422], [27.844945, -82.792501], [27.7379882, -82.7080321], [28.2375794, -82.3471278], [27.776811, -82.641157], [27.9404107, -82.3217459], [27.9646718, -82.5206425], [28.0536294, -82.4044188], [27.7823648981, -82.7816953479], [27.9444574, -82.4578244], [28.4934721999, -82.546930168], [28.0720088, -82.5109518], [28.1943032, -82.4986764], [27.9263727, -82.2859355], [28.0745649, -82.4599126], [28.07347, -82.459879], [27.865613, -82.7199909], [27.9788772, -82.8279609], [27.9210171, -82.3272616], [28.0662007, -82.6354932], [27.8928435529, -82.7453122398], [27.963, -82.777749], [27.7715736064, -82.6756190881], [27.9600238, -82.4444005], [28.0114997, -82.5828401], [27.8718285, -82.7502853], [27.7717231748, -82.6383055959], [27.964721464, -82.5198229405], [27.9279550671, -82.4784045787], [27.9963703, -82.580954], [28.2505165, -82.3737262], [28.497700000000002, -82.650015], [28.0686496, -82.5751466], [27.9588017985, -82.2789713027], [27.9345506, -82.2874462], [27.971329, -82.7078619], [27.944153, -82.46033], [28.185208, -82.406265], [28.1948998, -82.3542155], [28.0148425, -82.1231756], [27.8669377, -82.6450314], [28.4352625, -82.5669664], [28.4348331, -82.5427423], [28.056632, -82.4348671], [27.9451907, -82.7880287], [27.925332, -82.325395], [27.9916199, -82.7303756], [27.7969762597, -82.6381678127], [27.9684516983, -82.7621585038], [27.713401, -82.394372], [27.961201, -82.72336], [28.0424255, -82.5124529], [28.0451503082, -82.6812278379], [27.923037933, -82.4930161956], [27.9822896, -82.7057138], [28.4919153, -82.544815], [27.9910123, -82.1221107244], [27.7846206, -82.6383517], [28.2638132, -82.492625], [27.9082595, -82.2909146], [28.187946572, -82.3500558385], [27.8940624, -82.2719595], [28.0439, -82.6769], [27.894047, -82.2572688], [27.9112563, -82.315876], [27.8585758, -82.3397635], [27.7951457, -82.7299515], [27.870901, -82.7435853], [27.920067, -82.4989209], [28.290178, -

# %%
#Voy a setear todos los valores de la columna state como FL.
df_business_florida['state'] = 'FL'

# %%
#Volvemos a revisar los nulos
df_business_florida.isnull().sum()
# Out:
# business_id        0
# name               0
# address            0
# city               0
# state              0
# postal_code        0
# latitude           0
# longitude          0
# stars              0
# review_count       0
# is_open            0
# attributes      2592
# categories        21
# hours           3445
# dtype: int64

# %%
#Me interesa conocer la categoría del negocio (restaurantes) por lo que eliminaré los valores donde no tengo información de la categoría
df_business_florida[df_business_florida['categories'].isnull()]
# Out:
#                    business_id                                          name  \
# 3324    _obl2-rphXvtzP3y_ekV1Q                      Certegy Payment Services
# 13023   cs7i8-NtrT2P4dMYa2fX-g                                    Direct USA
# 15060   NpQowTAUYGeylRCAsJx9UA                                Skaters Choice
# 17615   7cEbbI3wjuGSsJUIGdrnzg                                          Qmar
# 38638   hzHCWiKeIGFJfqyeCqyYdg                             Sunstar Ambulance
# 39187   0_uuEqZbJcUl-qsLh_VOiw  East Richey Lawn Mower & Small Engine Repair
# 42434   cer9BbiI0dySmonxtleEJA         Babcock Healthcare Education Services
# 56288   sTrYR2vw0sF818AljClf5w                    Foundational Health Center
# 60542   w2qqUDq35WmLU00QNVfnkg                                King Logistics
# 63297   GVohCyKOOYZ0L_x9sU_Guw                                  Greek Unique
# 74453   9AZDrl6u0PxgWsgSYw6WTQ                          C & S Auto Interiors
# 86597   RiTqgQAQ8Ia2TClbw-2lvw                       Felix Tailoring Company
# 87394   M5-6JhEfZV_W8aEjHZATLA                            Rizzetta & Company
# 90835   HdfZK4F6XbZKU0b82A-H4A           Lifepath Hospice Thrift Store-Tampa
# 92083   ZpjUwGby6Hsg_qwFzqW82g               Pasco Imaging & Open Mri Center
# 103697  DE_DjwgYZTuHPD8YY9fWvg                               It's Just Lunch
# 116600  pKAT-F13_lI6LxKaO1Ao3A                                  Kings Realty
# 125341  fylWyDwRiAMlfujhRY4tnw              Vinyl Fever Cd's Records & Tapes
# 139352  Z3jvv4S-npJEDTRHtaPmxg                            Suncoast Designers
# 144328  szluot9mpdIAnUDGi27__w                         Anchor Pools and Spas
# 145039  s54FBcv78I6QNjqznP9oKw           Superior Fence and Rail of Pinellas
#
#                           address              city state postal_code  \
# 3324       11601 Roosevelt Blvd N  Saint Petersburg    FL       33716
# 13023       6201 Johns Rd, Ste 12             Tampa    FL       33634
# 15060          5121 N Armenia Ave             Tampa    FL       33603
# 17615          424 N Pinellas Ave    Tarpon Springs    FL       34689
# 38638           12490 Ulmerton Rd             Largo    FL       33774
# 39187      6721 Massachusetts Ave   New Port Richey    FL       34653
# 42434              2628 5th Ave N  Saint Petersburg    FL       33713
# 56288         7241 Bryan Dairy Rd          Seminole    FL       33777
# 60542            6002 Benjamin Rd             Tampa    FL       33634
# 63297   5025 E Fowler Ave, Ste 18             Tampa    FL       33617
# 74453             10930 49th St N  Saint Petersburg    FL       33762
# 86597    4058 Fiesta Plz, Ste 103             Tampa    FL       33607
# 87394           5844 Old Pasco Rd     Wesley Chapel    FL       33544
# 90835      4802 Gunn Hwy, Ste 124             Tampa    FL       33624
# 92083              7615 Jacque Rd            Hudson    FL       34667
# 103697   100 S Ashley Dr, Ste 275             Tampa    FL       33602
# 116600            504 S Kings Ave           Brandon    FL       33511
# 125341        4110 Henderson Blvd             Tampa    FL       33629
# 139352             15050 Labor Pl            Hudson    FL       34667
# 144328              810 49th St E          Palmetto    FL       34221
# 145039            1400 Starkey Rd             Largo    FL       33771
#
#          latitude  longitude stars review_count is_open attributes categories  \
# 3324    27.877463 -82.653546   1.0            7       1       None       None
# 13023   28.007857 -82.549116   1.0            5       1       None       None
# 15060   27.993196 -82.483378   4.5            8       1       None       None
# 17615   28.150341 -82.756441   5.0            7       1       None       None
# 38638   27.886142 -82.810522   1.0            5       1       None       None
# 39187   28.259008 -82.703231   2.0            8       1       None       None
# 42434   27.777173  -82.66924   2.5            5       1       None       None
# 56288   27.872999 -82.738997   3.5            5       1       None       None
# 60542   28.002098 -82.542488   2.0            5       1       None       None
# 63297   28.053639  -82.40048   3.5            5       1       None       None
# 74453   27.871492 -82.700757   4.5            6       1       None       None
# 86597   27.975769 -82.486048   3.5            5       1       None       None
# 87394   28.241467 -82.363201   1.0            5       1       None       None
# 90835    28.05214 -82.525296   3.0            6       1       None       None
# 92083   28.358718 -82.688633   2.5            6       1       None       None
# 103697  27.944457 -82.457824   1.0            9       1       None       None
# 116600  27.931885 -82.294507   1.0            5       1       None       None
# 125341  27.927386 -82.512611   4.5            5       0       None       None
# 139352  28.376194 -82.668344   3.5            6       1       None       None
# 144328  27.558259  -82.55616   2.5            5       1       None       None
# 145039  27.903442 -82.762799   1.5           10       1       None       None
#
#        hours
# 3324    None
# 13023   None
# 15060   None
# 17615   None
# 38638   None
# 39187   None
# 42434   None
# 56288   None
# 60542   None
# 63297   None
# 74453   None
# 86597   None
# 87394   None
# 90835   None
# 92083   None
# 103697  None
# 116600  None
# 125341  None
# 139352  None
# 144328  None
# 145039  None

# %%
#Eliminamos los nulos de la columna categories
df_business_florida= df_business_florida.dropna(subset=['categories'])

# %%
#Revisamos que los valores se hallan eliminado correctamente
df_business_florida.isnull().sum()
# Out:
# business_id        0
# name               0
# address            0
# city               0
# state              0
# postal_code        0
# latitude           0
# longitude          0
# stars              0
# review_count       0
# is_open            0
# attributes      2571
# categories         0
# hours           3424
# dtype: int64

# %%
#Eliminamos las columnas que no utilizaré para mi análisis
df_business_florida=df_business_florida.drop(columns=['postal_code','is_open','attributes','hours'])

# %%
#Verifico la eliminación de las columnas
df_business_florida.head()
# Out:
#                business_id                   name                    address  \
# 7   qkRM_2X51Yqxk3btlwAQIg         Temple Beth-El         400 Pasadena Ave S
# 10  UJsufbvfyfONHeWdvAHKjA              Marshalls  21705 Village Lakes Sc Dr
# 11  eEOYSgkmpB90uNA7lDOMRA  Vietnamese Food Truck
# 13  jaxMSoInw8Poo3XeMJt8lQ           Adams Dental          15 N Missouri Ave
# 14  0bPLkL0QhhPO5kt1_EXmNQ   Zio's Italian Market              2575 E Bay Dr
#
#               city state   latitude  longitude stars review_count  \
# 7   St. Petersburg    FL   27.76659 -82.732983   3.5            5
# 10   Land O' Lakes    FL  28.190459  -82.45738   3.5            6
# 11       Tampa Bay    FL  27.955269  -82.45632   4.0           10
# 13      Clearwater    FL  27.966235 -82.787412   5.0           10
# 14           Largo    FL  27.916116 -82.760461   4.5          100
#
#                                            categories
# 7                 Synagogues, Religious Organizations
# 10               Department Stores, Shopping, Fashion
# 11         Vietnamese, Food, Restaurants, Food Trucks
# 13  General Dentistry, Dentists, Health & Medical,...
# 14        Food, Delis, Italian, Bakeries, Restaurants

# %%
# Buscar 'restaurant' o 'restaurante' en la columna 'categories'
filtro = df_business_florida['categories'].str.contains('restaurant|restaurante', case=False, regex=True)

# %%
# Filtrar el DataFrame para obtener las filas que contienen 'restaurant' o 'restaurante'
df_business_florida = df_business_florida[filtro]

# %%
#Verificamos que se haya filtrado correctamente
df_business_florida
# Out:
#                    business_id                           name  \
# 11      eEOYSgkmpB90uNA7lDOMRA          Vietnamese Food Truck
# 14      0bPLkL0QhhPO5kt1_EXmNQ           Zio's Italian Market
# 58      uI9XODGY_2_ieTE6xJ0myw                    Roman Forum
# 59      JgpnXv_0XhV3SfbfB50nxw                    Joe's Pizza
# 79      pJfh3Ct8iL58NZa8ta-a5w        Top Shelf Sports Lounge
# ...                        ...                            ...
# 150232  Scd-rcsQCn60t1sHHFv-og                    First Watch
# 150249  8MzF1Tlgz0pOkxmhP5dYzA              El Cap Restaurant
# 150262  -bZQH8yjm7ntTyGeLQwh8Q    Farmer's Kitchen Restaurant
# 150271  BIyT7Kr7tMJqlfp4oOOYQg               Copper Bell Cafe
# 150292  esBGrrmuZzSiECyRBoKvvA  Colony Grill - St. Petersburg
#
#                             address            city state   latitude  \
# 11                                        Tampa Bay    FL  27.955269
# 14                    2575 E Bay Dr           Largo    FL  27.916116
# 58           10440 N Dale Mabry Hwy           Tampa    FL  28.046203
# 59            2038 N Dale Mabry Hwy           Tampa    FL  27.960514
# 79          3173 Cypress Ridge Blvd   Wesley Chapel    FL  28.196252
# ...                             ...             ...   ...        ...
# 150232  4045 N Tyrone Blvd, Ste 204  St. Petersburg    FL  27.808314
# 150249                3500 4th St N  St. Petersburg    FL   27.80414
# 150262                3500 E Bay Dr           Largo    FL  27.916787
# 150271             11228 Boyette Rd       Riverview    FL  27.853745
# 150292              670 Central Ave  St. Petersburg    FL  27.770872
#
#         longitude stars review_count  \
# 11      -82.45632   4.0           10
# 14     -82.760461   4.5          100
# 58     -82.505053   4.0           23
# 59     -82.506127   4.0           35
# 79     -82.380615   4.5           95
# ...           ...   ...          ...
# 150232  -82.75211   3.5          183
# 150249 -82.638855   3.5          414
# 150262 -82.750395   4.0            6
# 150271 -82.316887   3.5           49
# 150292 -82.643069   4.5           38
#
#                                                categories
# 11             Vietnamese, Food, Restaurants, Food Trucks
# 14            Food, Delis, Italian, Bakeries, Restaurants
# 58                   Restaurants, American (New), Italian
# 59                                     Restaurants, Pizza
# 79      Burgers, Sports Bars, Bars, Lounges, Restauran...
# ...                                                   ...
# 150232  Cafes, Restaurants, Breakfast & Brunch, Americ...
# 150249       American (Traditional), Burgers, Restaurants
# 150262                    Sandwiches, Restaurants, Diners
# 150271             Breakfast & Brunch, Cafes, Restaurants
# 150292  Bars, Beer Bar, Nightlife, Wine Bars, Pizza, R...
#
# [8728 rows x 10 columns]

# %%
#Exportamos a csv
df_business_florida.to_csv('yelp_business_florida.csv', index=False)

# %% [markdown]
# ## Reviews

# %%
#Importamos en un dataframe la información sobre las review
with open("Data/Yelp/review.json",'r', encoding='utf-8') as f:
    review=[json.loads(line) for line in f]
df_review=pd.DataFrame(review)

# %%
#Observamos la información de nuestro dataframe
df_review.head()
# Out:
#                 review_id                 user_id             business_id  \
# 0  KU_O5udG6zpxOg-VcAEodg  mh_-eMZ6K5RLWhZyISBhwA  XQfwVwDr-v0ZS3_CbbE5Xw
# 1  BiTunyQ73aT9WBnpR9DZGw  OyoGAe7OKpv6SyGZT5g77Q  7ATYjTIgM3jUlt4UM3IypQ
# 2  saUsX_uimxRlCVr67Z4Jig  8g_iMtfSiwikVnbP2etR0A  YjUWPpI6HXG530lwP-fb2A
# 3  AqPFMleE6RsU23_auESxiA  _7bHUi9Uuf5__HHc_Q8guQ  kxX2SOes4o-D3ZQBkiMRfA
# 4  Sx8TMOWLNuJBWer-0pcmoA  bcjbaE6dDog4jkNY91ncLQ  e4Vwtrqf-wpJfwesgvdgxQ
#
#    stars  useful  funny  cool  \
# 0    3.0       0      0     0
# 1    5.0       1      0     1
# 2    3.0       0      0     0
# 3    5.0       1      0     1
# 4    4.0       1      0     1
#
#                                                 text                 date
# 0  If you decide to eat here, just be aware it is...  2018-07-07 22:09:11
# 1  I've taken a lot of spin classes over the year...  2012-01-03 15:28:18
# 2  Family diner. Had the buffet. Eclectic assortm...  2014-02-05 20:30:30
# 3  Wow!  Yummy, different,  delicious.   Our favo...  2015-01-04 00:01:03
# 4  Cute interior and owner (?) gave us tour of up...  2017-01-14 20:54:15

# %%
#Verificamos las dimensiones de nuestro dataframe
df_review.shape
# Out:
# (6990280, 9)

# %%
#Revisamos si tenemos valores nulos
df_review.isnull().sum()
# Out:
# review_id      0
# user_id        0
# business_id    0
# stars          0
# useful         0
# funny          0
# cool           0
# text           0
# date           0
# dtype: int64

# %%
#Haremos un merge entre el dataframe de df_business_florida y df_reviews para filtrar las reviews que son del estado de Florida
df_reviews_florida=df_review.merge(df_business_florida, on='business_id', how='inner')

# %%
#Chequeamos que se haya realizado correctamente el merge
df_reviews_florida.head()
# Out:
#                 review_id                 user_id             business_id  \
# 0  OAhBYw8IQ6wlfw1owXWRWw  1C2lxzUo1Hyye4RFIXly3g  BVndHaLihEYbr76Z0CMEGw
# 1  R3TNDNoRUiVfRgvvczy0mg  -Dt5o6GpQcXQfVeWpHNtDg  BVndHaLihEYbr76Z0CMEGw
# 2  OZpHUjMx5vyK0Hn2Uim_AQ  kiTsCsc_vtGXnzVz738w2g  BVndHaLihEYbr76Z0CMEGw
# 3  dmjtUSlyc-3EA1Tv26AWJw  NKFBcrL56W7eHxPXxyPTxA  BVndHaLihEYbr76Z0CMEGw
# 4  kcV2upXjWLWuJPAt9QICbw  ZuF1R91KH924zJwPTmFi4g  BVndHaLihEYbr76Z0CMEGw
#
#    stars_x  useful  funny  cool  \
# 0      5.0       0      0     0
# 1      5.0       1      1     1
# 2      5.0       0      0     0
# 3      2.0       0      0     0
# 4      4.0       0      0     0
#
#                                                 text                 date  \
# 0  Great place for breakfast! I had the waffle, w...  2014-10-11 16:22:06
# 1  We came here based on the recommendation we re...  2018-04-15 19:51:54
# 2  We found this place by searching yelp and it d...  2014-11-15 16:49:09
# 3  Had supper about 5:00pm, 7/10/17, and was disa...  2017-07-10 21:48:06
# 4  Good little mom and pop breakfast place. The f...  2017-09-23 13:20:51
#
#             name                address   city state   latitude  longitude  \
# 0  Mamas Kitchen  5524 S Dale Mabry Hwy  Tampa    FL  27.884852 -82.506004
# 1  Mamas Kitchen  5524 S Dale Mabry Hwy  Tampa    FL  27.884852 -82.506004
# 2  Mamas Kitchen  5524 S Dale Mabry Hwy  Tampa    FL  27.884852 -82.506004
# 3  Mamas Kitchen  5524 S Dale Mabry Hwy  Tampa    FL  27.884852 -82.506004
# 4  Mamas Kitchen  5524 S Dale Mabry Hwy  Tampa    FL  27.884852 -82.506004
#
#   stars_y review_count                                         categories
# 0     4.5          162  Sandwiches, Restaurants, American (New), Ameri...
# 1     4.5          162  Sandwiches, Restaurants, American (New), Ameri...
# 2     4.5          162  Sandwiches, Restaurants, American (New), Ameri...
# 3     4.5          162  Sandwiches, Restaurants, American (New), Ameri...
# 4     4.5          162  Sandwiches, Restaurants, American (New), Ameri...

# %%
#Eliminamos las columnas que no utilizaremos
df_reviews_florida.drop(columns=['useful', 'funny', 'cool', 'address', 'state', 'stars_y'])
# Out:
#                      review_id                 user_id  \
# 0       OAhBYw8IQ6wlfw1owXWRWw  1C2lxzUo1Hyye4RFIXly3g
# 1       R3TNDNoRUiVfRgvvczy0mg  -Dt5o6GpQcXQfVeWpHNtDg
# 2       OZpHUjMx5vyK0Hn2Uim_AQ  kiTsCsc_vtGXnzVz738w2g
# 3       dmjtUSlyc-3EA1Tv26AWJw  NKFBcrL56W7eHxPXxyPTxA
# 4       kcV2upXjWLWuJPAt9QICbw  ZuF1R91KH924zJwPTmFi4g
# ...                        ...                     ...
# 792112  qDlqRGqY2psedI7VTixwaQ  4eUV_L1SV4UXlKXL4M7cnA
# 792113  WmmYAopcUHQCjKSIkPWD5Q  w-Dy7B6aZbBImMTVqyYJCA
# 792114  _H-RZA5e-mLAU3jY-KkpIg  ZNPC_Ul-q_dGrAErZEwVTg
# 792115  MYEUStZw8Dz0BAWLETgBfg  QUic4Ja79PQ7wU5fHlBDOQ
# 792116  axERWK6U3iuGVA1gg-SE2A  giQSReOdlfwPd9dND2FvDg
#
#                    business_id  stars_x  \
# 0       BVndHaLihEYbr76Z0CMEGw      5.0
# 1       BVndHaLihEYbr76Z0CMEGw      5.0
# 2       BVndHaLihEYbr76Z0CMEGw      5.0
# 3       BVndHaLihEYbr76Z0CMEGw      2.0
# 4       BVndHaLihEYbr76Z0CMEGw      4.0
# ...                        ...      ...
# 792112  dms2DI0DgFicvwLPlELlKA      5.0
# 792113  dms2DI0DgFicvwLPlELlKA      5.0
# 792114  dms2DI0DgFicvwLPlELlKA      4.0
# 792115  dms2DI0DgFicvwLPlELlKA      5.0
# 792116  dms2DI0DgFicvwLPlELlKA      2.0
#
#                                                      text  \
# 0       Great place for breakfast! I had the waffle, w...
# 1       We came here based on the recommendation we re...
# 2       We found this place by searching yelp and it d...
# 3       Had supper about 5:00pm, 7/10/17, and was disa...
# 4       Good little mom and pop breakfast place. The f...
# ...                                                   ...
# 792112  This is a great European Market with fresh veg...
# 792113  Having lived in St Pete for a few years I like...
# 792114  To set the record straight, this is not a rest...
# 792115  What a hidden gem! There are all sorts of Euro...
# 792116  5/5 for authentic greek take out food and 1/5 ...
#
#                        date                             name  \
# 0       2014-10-11 16:22:06                    Mamas Kitchen
# 1       2018-04-15 19:51:54                    Mamas Kitchen
# 2       2014-11-15 16:49:09                    Mamas Kitchen
# 3       2017-07-10 21:48:06                    Mamas Kitchen
# 4       2017-09-23 13:20:51                    Mamas Kitchen
# ...                     ...                              ...
# 792112  2020-01-25 22:46:30  Kalina's Coffee & European Food
# 792113  2021-12-15 01:59:18  Kalina's Coffee & European Food
# 792114  2018-08-04 16:12:18  Kalina's Coffee & European Food
# 792115  2020-09-20 23:37:02  Kalina's Coffee & European Food
# 792116  2021-01-25 05:26:04  Kalina's Coffee & European Food
#
#                     city   latitude  longitude review_count  \
# 0                  Tampa  27.884852 -82.506004          162
# 1                  Tampa  27.884852 -82.506004          162
# 2                  Tampa  27.884852 -82.506004          162
# 3                  Tampa  27.884852 -82.506004          162
# 4                  Tampa  27.884852 -82.506004          162
# ...                  ...        ...        ...          ...
# 792112  Saint Petersburg  27.830603 -82.645942            9
# 792113  Saint Petersburg  27.830603 -82.645942            9
# 792114  Saint Petersburg  27.830603 -82.645942            9
# 792115  Saint Petersburg  27.830603 -82.645942            9
# 792116  Saint Petersburg  27.830603 -82.645942            9
#
#                                                categories
# 0       Sandwiches, Restaurants, American (New), Ameri...
# 1       Sandwiches, Restaurants, American (New), Ameri...
# 2       Sandwiches, Restaurants, American (New), Ameri...
# 3       Sandwiches, Restaurants, American (New), Ameri...
# 4       Sandwiches, Restaurants, American (New), Ameri...
# ...                                                   ...
# 792112  Restaurants, Delis, Modern European, Coffee & ...
# 792113  Restaurants, Delis, Modern European, Coffee & ...
# 792114  Restaurants, Delis, Modern European, Coffee & ...
# 792115  Restaurants, Delis, Modern European, Coffee & ...
# 792116  Restaurants, Delis, Modern European, Coffee & ...
#
# [792117 rows x 12 columns]

# %%
df_reviews_florida = df_reviews_florida.rename(columns={'stars_x': 'stars'})

# %%
df_reviews_florida['date'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 792117 entries, 0 to 792116
# Series name: date
# Non-Null Count   Dtype
# --------------   -----
# 792117 non-null  object
# dtypes: object(1)
# memory usage: 6.0+ MB

# %%
df_reviews_florida['date'] = pd.to_datetime(df_reviews_florida['date'])

# %%
df_reviews_florida['date'] = df_reviews_florida['date'].dt.date

# %%
df_reviews_florida['date'].min()
# Out:
# datetime.date(2005, 7, 14)

# %%
df_reviews_florida['date'].max()
# Out:
# datetime.date(2022, 1, 19)

# %%
date_min = pd.to_datetime('2017-01-01').date()
date_max = pd.to_datetime('2022-01-19').date()

# %%
df_reviews_florida_date = df_reviews_florida[(df_reviews_florida['date']>= date_min) & (df_reviews_florida['date']<= date_max)]

# %%
df_reviews_florida_date
# Out:
#                      review_id                 user_id  \
# 1       R3TNDNoRUiVfRgvvczy0mg  -Dt5o6GpQcXQfVeWpHNtDg
# 3       dmjtUSlyc-3EA1Tv26AWJw  NKFBcrL56W7eHxPXxyPTxA
# 4       kcV2upXjWLWuJPAt9QICbw  ZuF1R91KH924zJwPTmFi4g
# 8       7VA-MRcyxibjlHexm_hTyw  gvkHURdz5M-bK7XdIbKDgQ
# 15      x41uAy2kh0xWyVGQ4PrEew  pk-iV4rlRNvZBQuk_79_og
# ...                        ...                     ...
# 792112  qDlqRGqY2psedI7VTixwaQ  4eUV_L1SV4UXlKXL4M7cnA
# 792113  WmmYAopcUHQCjKSIkPWD5Q  w-Dy7B6aZbBImMTVqyYJCA
# 792114  _H-RZA5e-mLAU3jY-KkpIg  ZNPC_Ul-q_dGrAErZEwVTg
# 792115  MYEUStZw8Dz0BAWLETgBfg  QUic4Ja79PQ7wU5fHlBDOQ
# 792116  axERWK6U3iuGVA1gg-SE2A  giQSReOdlfwPd9dND2FvDg
#
#                    business_id  stars  useful  funny  cool  \
# 1       BVndHaLihEYbr76Z0CMEGw    5.0       1      1     1
# 3       BVndHaLihEYbr76Z0CMEGw    2.0       0      0     0
# 4       BVndHaLihEYbr76Z0CMEGw    4.0       0      0     0
# 8       BVndHaLihEYbr76Z0CMEGw    5.0       0      0     0
# 15      BVndHaLihEYbr76Z0CMEGw    5.0       0      0     0
# ...                        ...    ...     ...    ...   ...
# 792112  dms2DI0DgFicvwLPlELlKA    5.0       2      1     2
# 792113  dms2DI0DgFicvwLPlELlKA    5.0       0      0     0
# 792114  dms2DI0DgFicvwLPlELlKA    4.0       5      1     1
# 792115  dms2DI0DgFicvwLPlELlKA    5.0       6      3     4
# 792116  dms2DI0DgFicvwLPlELlKA    2.0      13      2     5
#
#                                                      text        date  \
# 1       We came here based on the recommendation we re...  2018-04-15
# 3       Had supper about 5:00pm, 7/10/17, and was disa...  2017-07-10
# 4       Good little mom and pop breakfast place. The f...  2017-09-23
# 8       Great food and comfortable atmosphere and supe...  2018-09-15
# 15      Mamas Kitchen is just like what the name says,...  2018-06-12
# ...                                                   ...         ...
# 792112  This is a great European Market with fresh veg...  2020-01-25
# 792113  Having lived in St Pete for a few years I like...  2021-12-15
# 792114  To set the record straight, this is not a rest...  2018-08-04
# 792115  What a hidden gem! There are all sorts of Euro...  2020-09-20
# 792116  5/5 for authentic greek take out food and 1/5 ...  2021-01-25
#
#                                    name                             address  \
# 1                         Mamas Kitchen               5524 S Dale Mabry Hwy
# 3                         Mamas Kitchen               5524 S Dale Mabry Hwy
# 4                         Mamas Kitchen               5524 S Dale Mabry Hwy
# 8                         Mamas Kitchen               5524 S Dale Mabry Hwy
# 15                        Mamas Kitchen               5524 S Dale Mabry Hwy
# ...                                 ...                                 ...
# 792112  Kalina's Coffee & European Food  6393 Dr Martin Luther King Jr St N
# 792113  Kalina's Coffee & European Food  6393 Dr Martin Luther King Jr St N
# 792114  Kalina's Coffee & European Food  6393 Dr Martin Luther King Jr St N
# 792115  Kalina's Coffee & European Food  6393 Dr Martin Luther King Jr St N
# 792116  Kalina's Coffee & European Food  6393 Dr Martin Luther King Jr St N
#
#                     city state   latitude  longitude stars_y review_count  \
# 1                  Tampa    FL  27.884852 -82.506004     4.5          162
# 3                  Tampa    FL  27.884852 -82.506004     4.5          162
# 4                  Tampa    FL  27.884852 -82.506004     4.5          162
# 8                  Tampa    FL  27.884852 -82.506004     4.5          162
# 15                 Tampa    FL  27.884852 -82.506004     4.5          162
# ...                  ...   ...        ...        ...     ...          ...
# 792112  Saint Petersburg    FL  27.830603 -82.645942     4.5            9
# 792113  Saint Petersburg    FL  27.830603 -82.645942     4.5            9
# 792114  Saint Petersburg    FL  27.830603 -82.645942     4.5            9
# 792115  Saint Petersburg    FL  27.830603 -82.645942     4.5            9
# 792116  Saint Petersburg    FL  27.830603 -82.645942     4.5            9
#
#                                                categories
# 1       Sandwiches, Restaurants, American (New), Ameri...
# 3       Sandwiches, Restaurants, American (New), Ameri...
# 4       Sandwiches, Restaurants, American (New), Ameri...
# 8       Sandwiches, Restaurants, American (New), Ameri...
# 15      Sandwiches, Restaurants, American (New), Ameri...
# ...                                                   ...
# 792112  Restaurants, Delis, Modern European, Coffee & ...
# 792113  Restaurants, Delis, Modern European, Coffee & ...
# 792114  Restaurants, Delis, Modern European, Coffee & ...
# 792115  Restaurants, Delis, Modern European, Coffee & ...
# 792116  Restaurants, Delis, Modern European, Coffee & ...
#
# [489564 rows x 18 columns]

# %%
#Exportamos a csv
df_reviews_florida_date.to_csv('yelp_reviews_florida.csv', index=False)

# %% [markdown]
# ## Users

# %%
#Leemos la información de los usuarios del .parquet
df_user=pd.read_parquet('Data/Yelp/user.parquet')

# %%
#Observamos los datos que tenemos en el dataframe
df_user.head()
# Out:
#                   user_id    name  review_count        yelping_since  useful  \
# 0  qVc8ODYU5SZjKXVBgXdI7w  Walker           585  2007-01-25 16:47:26    7217
# 1  j14WgRoU_-2ZE1aw1dXrJg  Daniel          4333  2009-01-25 04:35:42   43091
# 2  2WnXYQFK0hXEoTxPtV2zvg   Steph           665  2008-07-25 10:41:00    2086
# 3  SZDeASXq7o05mMNLshsdIA    Gwen           224  2005-11-29 04:38:33     512
# 4  hA5lMy-EnncsH4JoR-hFGQ   Karen            79  2007-01-05 19:40:59      29
#
#    funny   cool                                              elite  \
# 0   1259   5994                                               2007
# 1  13066  27281  2009,2010,2011,2012,2013,2014,2015,2016,2017,2...
# 2   1010   1003                           2009,2010,2011,2012,2013
# 3    330    299                                     2009,2010,2011
# 4     15      7
#
#                                              friends  fans  ...  \
# 0  NSCy54eWehBJyZdG2iE84w, pe42u7DcCH2QmI81NX-8qA...   267  ...
# 1  ueRPE0CX75ePGMqOFVj6IQ, 52oH4DrRvzzl8wh5UXyU0A...  3138  ...
# 2  LuO3Bn4f3rlhyHIaNfTlnA, j9B4XdHUhDfTKVecyWQgyA...    52  ...
# 3  enx1vVPnfdNUdPho6PH_wg, 4wOcvMLtU6a9Lslggq74Vg...    28  ...
# 4  PBK4q9KEEBHhFvSXCUirIw, 3FWPpM7KU1gXeOM_ZbYMbA...     1  ...
#
#    compliment_more  compliment_profile  compliment_cute  compliment_list  \
# 0               65                  55               56               18
# 1              264                 184              157              251
# 2               13                  10               17                3
# 3                4                   1                6                2
# 4                1                   0                0                0
#
#    compliment_note  compliment_plain  compliment_cool  compliment_funny  \
# 0              232               844              467               467
# 1             1847              7054             3131              3131
# 2               66                96              119               119
# 3               12                16               26                26
# 4                1                 1                0                 0
#
#    compliment_writer  compliment_photos
# 0                239                180
# 1               1521               1946
# 2                 35                 18
# 3                 10                  9
# 4                  0                  0
#
# [5 rows x 22 columns]

# %%
#Verificamos las dimensiones del dataframe
df_user.shape
# Out:
# (2105597, 22)

# %%
#Revisamos si hay valores nulos
df_user.isnull().sum()
# Out:
# user_id               0
# name                  0
# review_count          0
# yelping_since         0
# useful                0
# funny                 0
# cool                  0
# elite                 0
# friends               0
# fans                  0
# average_stars         0
# compliment_hot        0
# compliment_more       0
# compliment_profile    0
# compliment_cute       0
# compliment_list       0
# compliment_note       0
# compliment_plain      0
# compliment_cool       0
# compliment_funny      0
# compliment_writer     0
# compliment_photos     0
# dtype: int64

# %%
#Selecciono las columnas de interés
df_user=df_user[['user_id', 'name', 'review_count', 'yelping_since', 'average_stars']]

# %%
#Revisamos la correcta seleccion de las columnas
df_user.head()
# Out:
#                   user_id    name  review_count        yelping_since  \
# 0  qVc8ODYU5SZjKXVBgXdI7w  Walker           585  2007-01-25 16:47:26
# 1  j14WgRoU_-2ZE1aw1dXrJg  Daniel          4333  2009-01-25 04:35:42
# 2  2WnXYQFK0hXEoTxPtV2zvg   Steph           665  2008-07-25 10:41:00
# 3  SZDeASXq7o05mMNLshsdIA    Gwen           224  2005-11-29 04:38:33
# 4  hA5lMy-EnncsH4JoR-hFGQ   Karen            79  2007-01-05 19:40:59
#
#    average_stars
# 0           3.91
# 1           3.74
# 2           3.32
# 3           4.27
# 4           3.54

# %%
#Filtro el df de usuarios, con las reviews que son de Florida, para quedarme con un dataframe con solo los usuarios de Florida
df_users_florida = df_user[df_user['user_id'].isin(df_reviews_florida_date['user_id'])]

# %%
#Verificamos
df_users_florida
# Out:
#                         user_id       name  review_count        yelping_since  \
# 36       rppTTi-kfF8-qyiArNemag      Helen           460  2006-01-24 14:33:32
# 69       q7iWal_rXNSHkHeCMMvZxQ  Stephanie           500  2011-06-01 21:02:59
# 83       K7thO1n-vZ9PFYiC7nTR2w     Yelper          1554  2007-12-26 23:05:41
# 85       asAdx4Q3cAMykgPgtQt6cg  Sylvester           123  2010-08-31 13:25:09
# 142      2Od6rQYNvPUXQC2Go7vIqg  Catherine           986  2007-08-22 17:13:14
# ...                         ...        ...           ...                  ...
# 2105563  Fdojx8V99xKPZrZ4C_9X6Q        Mel            11  2013-04-18 17:18:02
# 2105575  2InIg5itoYPYkWIe4s5hRw    Mercy's            29  2015-07-19 22:13:56
# 2105580  DH-aSZOpX0jn3eVpCVokng      Ronny            65  2016-07-26 03:20:05
# 2105581  EcT7gTi5S3dNoWMshMXS2A    Kristin            22  2015-07-31 13:41:36
# 2105596  mZl-mH3ZIWLRSd_FfvrXFg    Jessica            30  2015-11-30 21:10:17
#
#          average_stars
# 36                3.33
# 69                3.95
# 83                3.68
# 85                4.20
# 142               3.63
# ...                ...
# 2105563           4.45
# 2105575           3.31
# 2105580           3.35
# 2105581           4.46
# 2105596           4.13
#
# [190260 rows x 5 columns]

# %%
#Exportamos a csv
df_users_florida.to_csv('yelp_users_florida.csv', index=False)
